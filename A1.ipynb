# %% [markdown]
# *JSC270, Winter 2020 - Prof. Chevalier*
#
# # <center>  Assignment 1 - Toronto Bike Share  </center>
#
# ### <center> Due date: February 3, 11:59pm </center>
# <center>  This assignment is individual. </center>
#
#
# ***

# %% [markdown]
# This assignment builds on the work initiated in the Tutorial 1.
#
# ## Data
#
# Use the 2016 Q3, 2016 Q4, and 2017 Toronto Bikeshare ridership data available at [https://open.toronto.ca/dataset/bike-share-toronto-ridership-data/ to answer the following questions](https://open.toronto.ca/dataset/bike-share-toronto-ridership-data/).
#
# Station information, including real time data, is available at [https://open.toronto.ca/dataset/bike-share-toronto/](https://open.toronto.ca/dataset/bike-share-toronto/).
#
# A [blog post](https://towardsdatascience.com/exploring-toronto-bike-share-ridership-using-python-3dc87d35cb62) was written on the 2017 data set.
#
# Historical weather data is available from a Government of Canada [website](https://climate.weather.gc.ca/climate_data/daily_data_e.html?StationID=51459&timeframe=2&StartYear=1840&EndYear=2019&Day=22&Year=2017&Month=1#). The weather data will need to be scraped (and not downloaded as csv files), then merged with the ridership data.
#
#
#
#
#
# ## Questions
#
# Use Python and Markdown in a Jupyter notebook to answer the following questions. In all of the questions below interpret your results, and identify limitations.
#
# **1.** Check the Law and Regulations on the [Historical Climate Data website](https://climate.weather.gc.ca/). Describe in a few sentences what you can and can't do with the data.
#
# **2.** Read through the questions below. (i) Create a brief plan of the variables that you plan to use to answer these questions, (ii) explore the variables using quantitative and visual methods, and (iii) rectify any inconsistencies you find through exploration.
#
# **3.** Define trip length in two ways. Create a variable in the data set where necessary.
#
# **4.** Is there a relationship between your two definitions of trip length?
#
# **5.** Do casual users take shorter trips compared to members? Answer to this question using both definitions from Question 2.
#
# **6.** Does season or weather affect trip length? Answer to this question using both definitions from Question 2.
#
#
#
#
# ## Instructions
#
# * Answer each question, and build a cohesive report using Markdown and Code cells.
#
# * **You are required to scrape the wheather data from the website directly.** Note that if you are stuck with the scraping, you can still answer Question 6 by downloading csv files of the data.
#
#
# ### How should the data be analysed?
#
# Answers to the questions above can use a variety of statistical methods. Be sure to explore the data using numerical and graphical methods. You can use methods that we have not covered in class if you wish. But, it's a good idea to check with an instructor or TA.
#
# Most questions involving data analysis can have multiple appropriate answers. There is no one correct answer to these questions, and there are several appropriate answers.
#
# The questions in this handout are just seed questions. You are required to explore each question in as much depth as possible, asking follow-up questions, and/or looking at the same question from multiple perspectives.
#
#
# ### What should the report contain?
#
# The report should contain:
#
# * **Title.** There should be an appropriate title, adequate summary, and complete information including your name and date.
#
# * **Introduction.** The purpose of the research should be clearly stated and the scope of what is considered in the report should be clear.
#
# * **Methods.** The role of each method should be clearly stated. The description of the analyses should be clear and unambiguous so that another data scientist could easily why you selected these methods. The methods should be described accurately.
#
# * **Results.** There should be appropriate tables and graphs. The results should be clearly stated in the context of the problem. The size and direction of significant results should be given. The results must be accurately stated. The research question should be adequately answered using the results.
#
# * **Conclusion / Discussion.** The results should be clearly and completely summarized. This section should also include a discussion of limitations and/or concerns and/or suggestions for future consideration as appropriate.
#
# **General Considerations.** The ideas should be presented in logical order, with well-organized sections, no grammatical, spelling, or punctuation errors, an appropriate level of technical detail, and be clear and easy to follow. Refer to the [blog post](https://towardsdatascience.com/exploring-toronto-bike-share-ridership-using-python-3dc87d35cb62) for an example of a good data science report.
#
#
#
#  <br>
#  <br>
#
#  # <p style="background-color: #EEEEEE;text-align:center;padding-top: 15px;padding-bottom: 15px;" >Submission and Grading </p>
#
# ## Submission
#
# **What should be submitted?**
#
# * A Jupyter notebook using Python that contains all the data analyses. The flow of the notebook should be Markdown and Code cells weaved together. In addition make sure to comment your code in the code cells.
#
# * Additional files that your notebook requires to compile properly (e.g. a data file).
#
# * A report from your Jupyter notebook exported as a html file without the code cells. This can be done using [nbconvert](https://nbconvert.readthedocs.io/en/latest/).
#
#
# **Where should the assignment be submitted?**
# * Commit your finished notebook (in both ipynb and html format) and any other files on the Github Classroom repository: [https://classroom.github.com/a/WObinpbJ](https://classroom.github.com/a/WObinpbJ)
# * Submit a pdf version of your notebook to Quercus (use "Print to pdf" of your html notebook).
#
#
# ## Evaluation
#
# This assignment will be graded according to the following marking scheme.
#
# | | Marks|
# |--- |--- |
# | Data Analysis | 45 |
# | Programming | 45 |
# | Wow factor | 10 |
# | **Total** | **100**|
#
#
# Rubrics for [data analysis](https://jsc270.github.io/assignment_rubrics.html#data_analysis_rubric), and [programming](https://jsc270.github.io/assignment_rubrics.html#programming_rubric) outline expectations for this assignment.
